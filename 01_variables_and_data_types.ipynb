# %% [markdown]
# # Variables and Basic Data Types
#
# ## Introduction
#
# ### Variables
#
# - Variables are fundamental building blocks in programming.
# - Variables are locations in memory used to store data.
# - They act as containers that store data in your computer's memory.
# - Think of variables as labeled boxes where you can store different types of information.
# - In Python, variables are dynamic, meaning you don't need to declare their type explicitly - Python figures it out automatically!
#
# <img src="images/variables.jpg" width="400">
# <img src="images/variables-1.png" width="400">
# <img src="images/variables-3.png" width="400">
#
# ### Data Types
# - Data types define what kind of data a variable can hold.
# - Python has several built-in data types, and in this lesson, we'll focus on the basic ones that you'll use most frequently.
#
# <img src="images/data-type-graph.png" width="400">
# <img src="images/data-types.png" width="400">
# <img src="images/basic-data-type-in-python.png" width="400">
#
#
#
# **What you'll learn:**
# - What variables are and how to create them
# - Variable naming rules and conventions
# - Basic data types: integers, floats, strings, and booleans
# - Type checking and type conversion
# - Basic operations with different data types
# - Multiple assignment and variable swapping

# %% [markdown]
# ---
# ## Part 1: Comprehensive Practice

# %% [markdown]
# ### Identifiers and Keywords
# - Identifiers are names used to identify variables, functions, classes, etc.
# - Keywords are reserved words in Python that have special meanings and cannot be used as identifiers.

# %%
# To see a list of keywords used in python
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 1.1 Creating Variables

# %%
# Creating a variable - basic syntax: variable_name = value
age = 25
print(age)

# Creating multiple variables
name = "Alice"
height = 5.6
is_student = True

print(name)
print(height)
print(is_student)
# Out:
# 25
# Alice
# 5.6
# True

# %% [markdown]
# ### 1.2 Variable Naming Rules and Conventions

# %%
# Variables Naming Conventions
# snake_case
# camelCase
# PascalCase

# Valid variable names
user_name = "John"
user_age = 30
user123 = "User with numbers"
_private_var = "Underscore prefix"
userName = "Camel case (not recommended in Python)"

print(user_name,user_age,user123,_private_var,userName)

# Invalid variable names (uncomment to see errors)
# 123user = "Cannot start with number"
# user-name = "Cannot use hyphens"
# user name = "Cannot have spaces"
# for = "Cannot use reserved keywords"

# Python naming convention: snake_case (recommended)
first_name = "Alice"
last_name = "Smith"
total_amount = 150.75
is_active = True

print(f"Best practice: {first_name} {last_name}")
# Out:
# John 30 User with numbers Underscore prefix Camel case (not recommended in Python)
# Best practice: Alice	Smith

# %% [markdown]
# ### 1.3 Variable Assignment and Reassignment

# %%
# Initial assignment
x = 10
print("Initial value:", x)

# Reassigning a new value
x = 20
print("After reassignment:", x)

# Variables can change types (dynamic typing)
x = "Now I'm a string!"
print("After type change:", x)

# Using a variable in calculation
score = 85
score = score + 10  # Add 10 to current score
print("New score:", score)
# Out:
# Initial value: 10
# After reassignment: 20
# After type change: Now I'm a string!
# New score: 95

# %% [markdown]
# ### 1.4 Data Type: Integer (int)

# %%
# Integers are whole numbers (positive, negative, or zero)
positive_num = 42
negative_num = -17
zero = 0

print(f"Positive: {positive_num/10}")
print("Negative:", negative_num/10)
print("Zero:", zero)

# Large integers (Python handles any size)
big_number = 999999999999999999999999999
print("Big number:", big_number)

# Integer operations
a = 10
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")  # Returns float
print(f"Floor Division: {a} // {b} = {a // b}")  # Returns integer
print(f"Modulus (remainder): {a} % {b} = {a % b}")
print(f"Exponentiation: {a} ** {b} = {a ** b}")
# Out:
# Positive: 42
# Negative: -17
# Zero: 0
# Big number: 999999999999999999999999999
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335
# Floor Division: 10 // 3 = 3
# Modulus (remainder): 10 % 3 = 1
# Exponentiation: 10 ** 3 = 1000

# %% [markdown]
# ### 1.5 Data Type: Float (float)

# %%
# Floats are decimal numbers
temperature = 98.6
price = 19.99
pi = 3.14159
negative_float = -45.7

print("Temperature:", temperature)
print("Price:", price)
print("Pi:", pi)
print("Negative float:", negative_float)



# Float operations
x = 10.5
y = 2.5

print("Addition:", x , "+" , y , "=", x + y)
print(f"Subtraction: {x} - {y} = {x - y}")
print(f"Multiplication: {x} * {y} = {x * y}")
print(f"Division: {x} / {y} = {x / y}")

# Mixing integers and floats
result = 10 + 5.5  # Result will be float
print(f"Integer + Float = {result} (type: float)")
# Out:
# Temperature: 98.6
# Price: 19.99
# Pi: 3.14159
# Negative float: -45.7
# Small number: 0.00015
# Large number: 3500000.0
# Addition: 10.5 + 2.5 = 13.0
# Subtraction: 10.5 - 2.5 = 8.0
# Multiplication: 10.5 * 2.5 = 26.25
# Division: 10.5 / 2.5 = 4.2
# Integer + Float = 15.5 (type: float)

# %% [markdown]
# ### 1.6 Data Type: String (str)

# %%
# Strings are sequences of characters
# Can use single or double quotes
message1 = "Hello, World!"
message2 = 'Hello, Python!'

print(message1)
print(message2)

# String with quotes inside
quote1 = "She said, 'Hello!'"
quote2 = 'He said, "Goodbye!"'

print(quote1)
print(quote2)

# Multi-line strings (triple quotes)
long_text = """This is a
multi-line
string."""

print(long_text)

# Empty string
empty = ""
print(f"Empty string: '{empty}'")

# String with numbers (still a string!)
zip_code = "90210"
phone = "555-1234"
print(f"Zip code: {zip_code}, Phone: {phone}")

# %% [markdown]
# ### 1.7 String Operations

# %%
# String concatenation (joining)
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name
print("Full name:", full_name)

# String repetition
laugh = "Ha" * 5
print(laugh)

line = "=" * 30
print(line)

# String length
text = "Python Programming"
print(f"The length of '{text}' is {len(text)} characters")

# String indexing (accessing individual characters)
word = "Python"
print(f"First character: {word[0]}")
print(f"Second character: {word[1]}")
print(f"Last character: {word[-1]}")
print(f"Second to last: {word[-2]}")

# String slicing
text = "Hello, World!"
print(f"First 5 characters: {text[0:5]}")
print(f"Characters from index 7: {text[7:]}")
print(f"Characters up to index 5: {text[:5]}")
print(f"Last 6 characters: {text[-6:]}")

# %% [markdown]
# ### 1.8 String Methods

# %%
# Common string methods
text = "  Hello, Python!  "

# Case conversion
print(f"Upper case: {text.upper()}")
print(f"Lower case: {text.lower()}")
print(f"Title case: {text.title()}")
print(f"Capitalize: {text.capitalize()}")

# Removing whitespace
print(f"Strip whitespace: '{text.strip()}'")
print(f"Left strip: '{text.lstrip()}'")
print(f"Right strip: '{text.rstrip()}'")

# Replace
message = "Hello, World!"
new_message = message.replace("World", "Python")
print(f"Original: {message}")
print(f"Replaced: {new_message}")

# Split (convert string to list)
sentence = "Python is awesome"
words = sentence.split()
print(f"Split: {words}")

# Count occurrences
text = "banana"
print(f"Number of 'a' in 'banana': {text.count('a')}")

# Find position
sentence = "Python is fun"
position = sentence.find("is")
print(f"Position of 'is': {position}")

# %% [markdown]
# ### 1.9 Data Type: Boolean (bool)

# %%
# Booleans represent True or False values
is_sunny = True
is_raining = False

print("Is it sunny?", is_sunny)
print("Is it raining?", is_raining)

# Booleans from comparisons
age = 18
is_adult = age >= 18
print(f"Is adult? {is_adult}")

# Comparison operators
x = 10
y = 5

print(f"{x} == {y}: {x == y}") 
 # Equal to
print(f"{x} != {y}: {x != y}")  # Not equal to
print(f"{x} > {y}: {x > y}")    # Greater than
print(f"{x} < {y}: {x < y}")    # Less than
print(f"{x} >= {y}: {x >= y}")  # Greater than or equal to
print(f"{x} <= {y}: {x <= y}")  # Less than or equal to

# Boolean with strings
name1 = "Alice"
name2 = "Bob"
print(f"'{name1}' == '{name2}': {name1 == name2}")
print(f"'{name1}' != '{name2}': {name1 != name2}")

# %% [markdown]
# ### 1.10 Logical Operators with Booleans

# %%
# Logical operators: and, or, not

# AND operator (both must be True)
has_ticket = True
has_id = True
can_enter = has_ticket and has_id
print(f"Can enter? {can_enter}")

has_ticket = True
has_id = False
can_enter = has_ticket and has_id
print(f"Can enter? {can_enter}")

# OR operator (at least one must be True)
is_weekend = True
is_holiday = False
can_relax = is_weekend or is_holiday
print(f"Can relax? {can_relax}")

# NOT operator (inverts the boolean)
is_raining = False
is_sunny = not is_raining
print(f"Is sunny? {is_sunny}")

# Combining logical operators
age = 25
has_license = True
can_rent_car = (age >= 21) and has_license
print(f"Can rent car? {can_rent_car}")
# Out:
# Can enter? True
# Can enter? False
# Can relax? True
# Is sunny? True
# Can rent car? True

# %% [markdown]
# ### 1.11 Checking Data Types - type() Function

# %%
# Using type() to check data types
age = 25
price = 19.99
name = "Alice"
is_student = True

print(f"Type of {age}: {type(age)}")
print(f"Type of {price}: {type(price)}")
print(f"Type of '{name}': {type(name)}")
print(f"Type of {is_student}: {type(is_student)}")

# Checking types in conditions
value = 42
if type(value) == int:
    print(f"{value} is an integer")

# Alternative: isinstance()
print(f"Is 42 an integer? {isinstance(42, int)}")
print(f"Is 'Hello' a string? {isinstance('Hello', str)}")
print(f"Is 3.14 a float? {isinstance(3.14, float)}")

# %% [markdown]
# ### 1.12 Type Conversion (Casting)

# %%
# Converting between types

# Integer to Float
num_int = 10
num_float = float(num_int)
print(f"Integer {num_int} to Float: {num_float}")

# Float to Integer (truncates decimal part)
num_float = 10.7
num_int = int(num_float)
print(f"Float {num_float} to Integer: {num_int}")

# String to Integer
str_num = "100"
int_num = int(str_num)
print(f"String '{str_num}' to Integer: {int_num}")
print(f"Type: {type(int_num)}")

# String to Float
str_num = "3.14"
float_num = float(str_num)
print(f"String '{str_num}' to Float: {float_num}")

# Integer/Float to String
age = 25
age_str = str(age)
print(f"Integer {age} to String: '{age_str}'")
print(f"Type: {type(age_str)}")

# Boolean to Integer
bool_true = True
bool_false = False
print(f"True to Integer: {int(bool_true)}")   # 1
print(f"False to Integer: {int(bool_false)}") # 0

# Integer to Boolean
print(f"0 to Boolean: {bool(0)}")      # False
print(f"1 to Boolean: {bool(1)}")      # True
print(f"42 to Boolean: {bool(42)}")    # True
print(f"-5 to Boolean: {bool(-5)}")    # True

# String to Boolean
print(f"Empty string to Boolean: {bool('')}")      # False
print(f"Non-empty string to Boolean: {bool('Hi')}") # True

# %% [markdown]
# ### 1.13 Type Conversion Errors

# %%
# Some conversions will cause errors

# This works
num_str = "123"
num = int(num_str)
print(f"Successful conversion: {num}")

# This will cause an error (uncomment to see)
# invalid_str = "Hello"
# num = int(invalid_str)  # ValueError: invalid literal for int()

# This will also cause an error (uncomment to see)
# decimal_str = "3.14"
# num = int(decimal_str)  # ValueError: invalid literal for int()

# Solution: convert to float first, then to int
decimal_str = "3.14"
num = int(float(decimal_str))
print(f"Converted '{decimal_str}' to integer: {num}")

# %% [markdown]
# ### 1.14 Multiple Assignment

# %%
# Assign same value to multiple variables
x = y = z = 0
print(f"x = {x}, y = {y}, z = {z}")

# Assign multiple values at once
name, age, city = "Alice", 25, "New York"
print(f"Name: {name}, Age: {age}, City: {city}")

# Unpacking
a, b, c = 1, 2, 3
print(f"a = {a}, b = {b}, c = {c}")

# Swapping variables
x = 10
y = 20
print(f"Before swap: x = {x}, y = {y}")

x, y = y, x  # Python magic!
print(f"After swap: x = {x}, y = {y}")

# %% [markdown]
# ### 1.15 Constants (Convention)

# %%
# Python doesn't have true constants, but we use UPPER_CASE by convention
# to indicate a value should not be changed

PI = 3.14159
GRAVITY = 9.8
MAX_SPEED = 120
COMPANY_NAME = "Tech Corp"

print(f"Pi: {PI}")
print(f"Gravity: {GRAVITY}")
print(f"Max Speed: {MAX_SPEED}")
print(f"Company: {COMPANY_NAME}")

# These can technically be changed, but shouldn't be
# PI = 3.14  # Don't do this!

# %% [markdown]
# ### 1.16 User Input and Type Conversion

# %%
# Getting user input (always returns a string)
# Note: input() will wait for user to type and press Enter

# Basic input
name = input("Enter your name: ")
print(f"Hello, {name}!")

# Converting input to integer
age_str = input("Enter your age: ")
age = int(age_str)
print(f"Next year you will be {age + 1} years old")

# Direct conversion (shorter way)
age = int(input("Enter your age: "))
print(f"In 5 years you will be {age + 5} years old")

# Float input
height = float(input("Enter your height in feet: "))
print(f"Your height is {height} feet")

# For demonstration without actual input
print("Input examples are commented out to avoid blocking execution")
print("Uncomment them when you want to test with actual user input")
# Out:
# Hello, uzair!
# Next year you will be 26 years old
# In 5 years you will be 25 years old
# Your height is 10.0 feet
# Input examples are commented out to avoid blocking execution
# Uncomment them when you want to test with actual user input

# %% [markdown]
# ### 1.17 Practical Examples

# %%
# Example 1: Simple calculator
num1=50
num2=20

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print("=== Simple Calculator ===")
print(f"{num1} + {num2} = {addition}")
print(f"{num1} - {num2} = {subtraction}")
print(f"{num1} * {num2} = {multiplication}")
print(f"{num1} / {num2} = {division:.2f}")

print()

# Example 2: Personal information
first_name = "John"
last_name = "Smith"
age = 28
height = 5.9
is_employed = True

full_name = first_name + " " + last_name

print("=== Personal Information ===")
print(f"Name: {full_name}")
print(f"Age: {age} years old")
print(f"Height: {height} feet")
print(f"Employed: {is_employed}")

print()

# Example 3: Shopping cart
item1 = "Laptop"
price1 = 999.99
quantity1 = 1

item2 = "Mouse"
price2 = 25.50
quantity2 = 2

subtotal1 = price1 * quantity1
subtotal2 = price2 * quantity2
total = subtotal1 + subtotal2

print("=== Shopping Cart ===")
print(f"{item1} x{quantity1}: ${subtotal1:.2f}")
print(f"{item2} x{quantity2}: ${subtotal2:.2f}")
print(f"Total: ${total:.2f}")
# Out:
# === Simple Calculator ===
# 50 + 20 = 70
# 50 - 20 = 30
# 50 * 20 = 1000
# 50 / 20 = 2.50
#
# === Personal Information ===
# Name: John Smith
# Age: 28 years old
# Height: 5.9 feet
# Employed: True
#
# === Shopping Cart ===
# Laptop x1: $999.99
# Mouse x2: $51.00
# Total: $1050.99000

# %% [markdown]
# ---
# ## Part 2: In-Class Tasks
#
# Now it's your turn! Complete these tasks during the class session.

# %% [markdown]
# ### Task 1: Create Variables
# Create variables for your favorite movie name (string), year released (integer), and rating out of 10 (float). Print all three variables.

# %%
# Write your code here

# %% [markdown]
# ### Task 2: Variable Reassignment
# Create a variable `score` with value 50. Then add 20 to it and print the result. Then multiply it by 2 and print again.

# %%
# Write your code here

# %% [markdown]
# ### Task 3: String Operations
# Create two variables: `first_name` and `last_name` with your name. Create a third variable `full_name` by concatenating them with a space. Print the full name and its length.

# %%
# Write your code here

# %% [markdown]
# ### Task 4: String Methods
# Create a variable with text "  python programming  " (with spaces). Use string methods to:
# 1. Remove the spaces
# 2. Convert to uppercase
# 3. Replace "PROGRAMMING" with "CODING"
#
# Print the result after each step.

# %%
# Write your code here

# %% [markdown]
# ### Task 5: Type Checking
# Create four variables with different types (int, float, string, boolean). Use the `type()` function to print the type of each variable.

# %%
# Write your code here

# %% [markdown]
# ### Task 6: Type Conversion
# Create a string variable with value "75". Convert it to integer, add 25 to it, and print the result.

# %%
# Write your code here

# %% [markdown]
# ### Task 7: Boolean Operations
# Create two variables: `temperature = 75` and `is_sunny = True`. Create a boolean variable `good_weather` that is True only if temperature is above 70 AND it's sunny. Print the result.

# %%
# Write your code here

# %% [markdown]
# ### Task 8: Multiple Assignment
# Use multiple assignment to create three variables in one line: `x = 5`, `y = 10`, `z = 15`. Then swap the values of x and z. Print before and after swapping.

# %%
# Write your code here

# %% [markdown]
# ### Task 9: String Indexing
# Create a variable `word = "Python"`. Print:
# 1. The first character
# 2. The last character
# 3. The first three characters
# 4. The last three characters

# %%
# Write your code here

# %% [markdown]
# ### Task 10: Simple Calculation
# Create variables for item price (29.99) and quantity (3). Calculate the total cost and print it with 2 decimal places.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 3: Homework Tasks
#
# Complete these tasks at home to reinforce your learning.

# %% [markdown]
# ### Homework Task 1: Personal Profile
# Create a personal profile with the following information stored in variables:
# - Full name
# - Age
# - Height (in feet, as float)
# - Favorite color
# - Is student (boolean)
#
# Print all information in a nicely formatted way. Example:
# ```
# ===== PROFILE =====
# Name: John Doe
# Age: 20 years
# Height: 5.8 feet
# Favorite Color: Blue
# Student: True
# ===================
# ```

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 2: Temperature Converter
# Create a variable `celsius` with a temperature value. Convert it to Fahrenheit using the formula: `F = (C × 9/5) + 32`
#
# Print both temperatures with appropriate labels. Format the output to 1 decimal place.

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 3: String Manipulation Challenge
# Start with the string: `message = "python is awesome"`
#
# Perform the following operations (print result after each):
# 1. Convert to title case
# 2. Convert to uppercase
# 3. Replace "AWESOME" with "AMAZING"
# 4. Count how many times the letter 'A' appears
# 5. Find the position of "AMAZING"

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 4: Rectangle Calculator
# Create variables for rectangle length and width. Calculate and print:
# - Perimeter (2 × length + 2 × width)
# - Area (length × width)
#
# Format your output nicely:
# ```
# Rectangle Dimensions:
# Length: 10
# Width: 5
# ---
# Perimeter: 30
# Area: 50
# ```

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 5: Age Calculator
# Create a variable `birth_year` with your birth year. Calculate your age by subtracting from the current year (2024). Also calculate:
# - How old you will be in 10 years
# - How old you were 5 years ago
#
# Print all three ages with labels.

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 6: Type Conversion Practice
# Given these string variables:
# ```python
# num1_str = "45"
# num2_str = "3.14"
# num3_str = "100"
# ```
#
# 1. Convert num1_str to integer and add 55
# 2. Convert num2_str to float and multiply by 2
# 3. Convert num3_str to integer, then to float, then back to string
#
# Print the type and value after each conversion.

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 7: Boolean Logic Practice
# Create the following variables:
# ```python
# age = 22
# has_license = True
# has_insurance = True
# is_raining = False
# ```
#
# Create boolean variables for:
# 1. `can_drive`: True if age >= 18 AND has license
# 2. `fully_prepared`: True if can_drive AND has insurance
# 3. `good_conditions`: True if NOT raining
# 4. `ready_to_go`: True if fully_prepared AND good_conditions
#
# Print each boolean with a descriptive message.

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 8: Shopping Receipt
# Create a shopping receipt with at least 3 items. For each item store:
# - Item name (string)
# - Price (float)
# - Quantity (integer)
#
# Calculate the subtotal for each item and the grand total. Format the output like a receipt:
# ```
# ========== RECEIPT ==========
# Apples    x3  $1.50  $4.50
# Bread     x2  $2.99  $5.98
# Milk      x1  $3.49  $3.49
# -----------------------------
# TOTAL:              $13.97
# =============================
# ```

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 9: BMI Calculator
# Create variables for weight in kilograms and height in meters. Calculate the BMI using the formula:
# ```
# BMI = weight / (height²)
# ```
#
# Print the result with 2 decimal places. Also create a boolean variable that is True if BMI is between 18.5 and 24.9 (healthy range).
#
# Example output:
# ```
# Weight: 70 kg
# Height: 1.75 m
# BMI: 22.86
# Healthy range: True
# ```

# %%
# Write your code here

# %% [markdown]
# ### Homework Task 10: Creative Variable Challenge
# Create a small program of your choice that uses:
# - At least 5 variables
# - At least 3 different data types
# - At least 2 mathematical operations
# - At least 1 string operation
# - At least 1 boolean comparison
#
# Ideas:
# - A grade calculator
# - A savings goal tracker
# - A movie collection manager
# - A simple game score tracker
# - Or anything creative you can think of!
#
# Be creative and have fun! 🎨

# %%
# Write your code here - Be Creative!

# %% [markdown]
# ---
# ## Summary
#
# Congratulations! You've learned about variables and basic data types in Python. Here's what we covered:
#
# 1. ✅ Creating and naming variables
# 2. ✅ Variable assignment and reassignment
# 3. ✅ Integer data type (int) and operations
# 4. ✅ Float data type (float) and operations
# 5. ✅ String data type (str) and operations
# 6. ✅ String methods (upper, lower, strip, replace, etc.)
# 7. ✅ String indexing and slicing
# 8. ✅ Boolean data type (bool) and logical operators
# 9. ✅ Type checking with type() and isinstance()
# 10. ✅ Type conversion (casting)
# 11. ✅ Multiple assignment and variable swapping
# 12. ✅ Constants convention
# 13. ✅ User input and type conversion
#
# These fundamentals are the foundation of all Python programming. Master them well!
#
# **Next Topic:** We'll learn about operators and expressions to do more complex calculations and comparisons!
